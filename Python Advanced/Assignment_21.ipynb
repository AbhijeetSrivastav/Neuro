# %% [markdown]
# Q1. What is a probability distribution, exactly? If the values are meant to be random, how can you
# predict them at all?

# %% [markdown]
# Ans:
#
# Probability Distribution describes how random variable are distributed over the data.
#
# In short what is likeliness of a variable to happen or not based on certain events already occurred.
#
# Thats why its random but we can guess or predict it.

# %% [markdown]
# Q2. Is there a distinction between true random numbers and pseudo-random numbers, if there is
# one? Why are the latter considered “good enough”?

# %% [markdown]
# Ans: Random numbers are true physical random numbers while pseudo random numbers are generated by algorithm based on certain seed thats why they are not true random this is why latter is considered good.

# %% [markdown]
# Q3. What are the two main factors that influence the behaviour of a &quot;normal&quot; probability distribution?

# %% [markdown]
# Ans:
#
# * Variance
# * Mean

# %% [markdown]
# Q4. Provide a real-life example of a normal distribution.

# %% [markdown]
# Ans:
#
# * Age of students in class
# * Width of a fruit
# * Height of children in a class
# etc

# %% [markdown]
# Q5. In the short term, how can you expect a probability distribution to behave? What do you think will
# happen as the number of trials grows?

# %% [markdown]
# Ans:
#
# Probability distribution is mathematical representation of random event that happen in real life.
#
# And Number of trials in experiments(event) is inversely proportional to the variance.
#
# So probability of predicting something will increase with increase of the trials.
#
# In short more the data better the prediction.

# %% [markdown]
# Q6. What kind of object can be shuffled by using random.shuffle?

# %% [markdown]
# Ans:
#
# * str
# * list
# * tuple

# %% [markdown]
# Q7. Describe the math package&#39;s general categories of functions.

# %% [markdown]
# Ans:
#
# * Trigonometric functions
# * Quadratic functions
# * Exponential functions
# * Hyperbolic functions
# * Periodic functions
# * Arithmetic functions
# * Logarithimic functions
# * Conversions to Integer

# %% [markdown]
# Q8. What is the relationship between exponentiation and logarithms?

# %% [markdown]
# Ans: Exponent  =  1 / Logarithms
#
# Basically they are inverse of each other.

# %% [markdown]
# Q9. What are the three logarithmic functions that Python supports?

# %% [markdown]
# Ans:
#
# * `log2(x)` log base 2
# * `log10(x)` log base 10
# * `log1p(x)` log base (1 + x)
